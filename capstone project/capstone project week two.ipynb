# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
df = pd.read_csv('Social Media Data for DSBA.csv')

# %%
df.head()
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001           Yes                           307.0  iOS and Android
# 1  1000002            No                           367.0              iOS
# 2  1000003           Yes                           277.0  iOS and Android
# 3  1000004            No                           247.0              iOS
# 4  1000005            No                           202.0  iOS and Android
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                  38570.0                              1
# 1                                   9765.0                              1
# 2                                  48055.0                              1
# 3                                  48720.0                              1
# 4                                  20685.0                              1
#
# ...

# %%
df.shape
# Out:
# (11760, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  object
#  2   Yearly_avg_view_on_travel_page                11179 non-null  float64
#  3   preferred_device                              11707 non-null  object
#  4   total_likes_on_outstation_checkin_given       11379 non-null  float64
#  5   yearly_avg_Outstation_checkins                11685 non-null  object
#  6   member_in_family                              11760 non-null  object
#  7   preferred_location_type                       11729 non-null  object
#  8   Yearly_avg_comment_on_travel_page             11554 non-null  float64
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# UserID
# Taken_product
# Yearly_avg_view_on_travel_page
# preferred_device
# total_likes_on_outstation_checkin_given
# yearly_avg_Outstation_checkins
# member_in_family
# preferred_location_type
# Yearly_avg_comment_on_travel_page
# total_likes_on_outofstation_checkin_received
# week_since_last_outstation_checkin
# following_company_page
# montly_avg_comment_on_company_page
# working_flag
# travelling_network_rating
# Adult_flag
# Daily_Avg_mins_spend_on_traveling_page

# %%
df.describe()
# Out:
#              UserID  Yearly_avg_view_on_travel_page  \
# count  1.176000e+04                    11179.000000
# mean   1.005880e+06                      280.830844
# std    3.394964e+03                       68.182958
# min    1.000001e+06                       35.000000
# 25%    1.002941e+06                      232.000000
# 50%    1.005880e+06                      271.000000
# 75%    1.008820e+06                      324.000000
# max    1.011760e+06                      464.000000
#
#        total_likes_on_outstation_checkin_given  \
# count                             11379.000000
# mean                              28170.481765
# std                               14385.032134
# min                                3570.000000
# 25%                               16380.000000
# 50%                               28076.000000
# 75%                               40525.000000
# max                              252430.000000
#
#        Yearly_avg_comment_on_travel_page  \
# ...

# %%
df.isna().sum()
# Out:
# UserID                                            0
# Taken_product                                     0
# Yearly_avg_view_on_travel_page                  581
# preferred_device                                 53
# total_likes_on_outstation_checkin_given         381
# yearly_avg_Outstation_checkins                   75
# member_in_family                                  0
# preferred_location_type                          31
# Yearly_avg_comment_on_travel_page               206
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                          103
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

df[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [UserID, Taken_product, Yearly_avg_view_on_travel_page, preferred_device, total_likes_on_outstation_checkin_given, yearly_avg_Outstation_checkins, member_in_family, preferred_location_type, Yearly_avg_comment_on_travel_page, total_likes_on_outofstation_checkin_received, week_since_last_outstation_checkin, following_company_page, montly_avg_comment_on_company_page, working_flag, travelling_network_rating, Adult_flag, Daily_Avg_mins_spend_on_traveling_page]
# Index: []

# %%
df.Yearly_avg_view_on_travel_page.unique()
# Out:
# array([307., 367., 277., 247., 202., 240.,  nan, 225., 285., 270., 262.,
#        217., 232., 255., 210., 165., 397., 180., 157., 330., 345., 292.,
#        322., 375., 195., 360., 412., 382., 300., 405., 435., 150., 187.,
#         42., 427., 352.,  35., 450., 135., 308., 368., 249., 205., 445.,
#        226., 287., 271., 263., 219., 234., 256., 212., 241., 399., 286.,
#        182., 159., 316., 332., 347., 248., 331., 294., 323., 376., 265.,
#        204., 309., 257., 346., 264., 361., 196., 278., 444., 272., 414.,
#        339., 443., 233., 280., 422., 174., 384., 302., 242., 181., 211.,
#        436., 279., 151., 377., 188., 189., 166., 406., 324., 197., 143.,
#        167., 383., 227., 144., 301., 429., 203., 250., 413., 338., 310.,
#        392., 317., 354., 400., 369., 137., 136., 295., 391., 353., 218.,
#        362., 428., 451., 430., 173., 190., 398., 355., 437., 407., 152.,
#        421., 158., 293., 235., 220., 340., 385., 370., 325., 415., 452.,
# ...

# %%
df.total_likes_on_outstation_checkin_given.unique()
# Out:
# array([ 38570.,   9765.,  48055.,  48720.,  20685.,  35175.,  46340.,
#            nan,   7560.,  45465.,  28315.,   5355.,  23450.,  47110.,
#          3605.,  48615.,  42665.,  12985.,  23555.,  42630.,  14665.,
#         13685.,  24465.,  44870.,  39375.,  24185.,  16695.,  51065.,
#          4375.,  31325.,  28455.,  44555.,  30415.,  31150.,  29820.,
#         39935.,  16240.,  43400.,  47495.,  34790.,  25235.,  47600.,
#         42385.,  50190.,  52080.,  38395.,  50505.,  18025.,  29855.,
#         39970.,  22925.,  39025.,  14945.,  22855.,  34615.,  50225.,
#         42805.,  29260.,  41825.,  46865.,  23240.,  11130.,  42875.,
#         46480.,  37870.,  19180.,   4620.,  26110.,  27160.,   6755.,
#         13895.,  33075.,  42490.,   3885.,  20055.,  40355.,  49000.,
#         18935.,  15120.,  10080.,  23415.,  18550.,  22120.,  46690.,
#         22330.,  38255.,  42595.,  47355.,  23870.,  17115.,  28245.,
# ...

# %%
df.Yearly_avg_comment_on_travel_page.unique()
# Out:
# array([ 94.,  61.,  92.,  56.,  40.,  79.,  81.,  67.,  44.,  84.,  49.,
#         31.,  93.,  50.,  51.,  80.,  96.,  78.,  45.,  82.,  53.,  83.,
#         58.,  72.,  48.,  42.,  41.,  86.,  97.,  75.,  33.,  37.,  73.,
#         nan,  98.,  47.,  71.,   3.,  43.,  99.,  59.,  95.,  57.,  76.,
#         87.,  66.,  55.,  32.,  52.,  70.,  62.,  64.,  63.,  60., 100.,
#         46.,  39.,  77.,  91.,  54.,  34.,  90.,  65.,  36.,  88.,  35.,
#         89.,  68.,  85.,  69.,  74.,  38., 106., 105., 103., 108., 111.,
#        104., 102., 109., 110., 112., 101., 107., 615., 114., 113., 215.,
#        815., 685., 118., 117., 115., 116., 121., 122., 120., 124., 119.,
#        125., 123.])

# %%
 df.Taken_product.value_counts()
# Out:
# No     9864
# Yes    1896
# Name: Taken_product, dtype: int64

# %%
df.preferred_device.value_counts()
# Out:
# Tab                4172
# iOS and Android    4134
# Laptop             1108
# iOS                1095
# Mobile              600
# Android             315
# Android OS          145
# ANDROID             134
# Other                 2
# Others                2
# Name: preferred_device, dtype: int64

# %%
df.yearly_avg_Outstation_checkins.value_counts()
# Out:
# 1     4543
# 2      844
# 10     682
# 9      340
# 7      336
# 3      336
# 8      320
# 5      261
# 4      256
# 16     255
# 6      236
# 11     229
# 24     223
# 23     215
# 29     215
# 18     208
# 15     206
# 26     199
# 20     199
# 25     198
# 28     180
# 19     176
# 14     167
# 17     160
# 12     159
# 22     152
# 13     150
# 21     143
# 27      96
# *        1
# Name: yearly_avg_Outstation_checkins, dtype: int64

# %%
df.member_in_family.value_counts()
# Out:
# 3        4561
# 4        3184
# 2        2256
# 1        1349
# 5         384
# Three      15
# 10         11
# Name: member_in_family, dtype: int64

# %%
df.preferred_location_type.value_counts()
# Out:
# Beach              2424
# Financial          2409
# Historical site    1856
# Medical            1845
# Other               643
# Big Cities          636
# Social media        633
# Trekking            528
# Entertainment       516
# Hill Stations       108
# Tour  Travel         60
# Tour and Travel      47
# Game                 12
# OTT                   7
# Movie                 5
# Name: preferred_location_type, dtype: int64

# %%
df.week_since_last_outstation_checkin.value_counts()
# Out:
# 1     3070
# 3     1766
# 2     1700
# 4     1118
# 0     1032
# 5      728
# 6      654
# 7      594
# 9      472
# 8      428
# 10     138
# 11      60
# Name: week_since_last_outstation_checkin, dtype: int64

# %%
df.following_company_page.value_counts()
# Out:
# No     8355
# Yes    3285
# 1        12
# 0         5
# Name: following_company_page, dtype: int64

# %%
df.working_flag.value_counts()
# Out:
# No     9952
# Yes    1808
# Name: working_flag, dtype: int64

# %%
df.travelling_network_rating.value_counts()
# Out:
# 3    3672
# 4    3456
# 2    2424
# 1    2208
# Name: travelling_network_rating, dtype: int64

# %%
df.Adult_flag.value_counts()
# Out:
# 0    5048
# 1    4768
# 2    1264
# 3     680
# Name: Adult_flag, dtype: int64

# %% [markdown]
# ## null values

# %%
df.isna().sum()
# Out:
# UserID                                            0
# Taken_product                                     0
# Yearly_avg_view_on_travel_page                  581
# preferred_device                                 53
# total_likes_on_outstation_checkin_given         381
# yearly_avg_Outstation_checkins                   75
# member_in_family                                  0
# preferred_location_type                          31
# Yearly_avg_comment_on_travel_page               206
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                          103
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (10456, 17)

# %% [markdown]
# # Correction of data

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### Adult Flag

# %%
df.Adult_flag.value_counts()
# Out:
# 0    4476
# 1    4249
# 2    1114
# 3     617
# Name: Adult_flag, dtype: int64

# %%
df.Adult_flag = df.Adult_flag.replace(2,1)
df.Adult_flag = df.Adult_flag.replace(3,1)

# %%
df.Adult_flag.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
#  ### travelling_network_rating

# %%
df.travelling_network_rating.value_counts()
# Out:
# 3    3291
# 4    3066
# 2    2147
# 1    1952
# Name: travelling_network_rating, dtype: int64

# %% [markdown]
# ### working_flag

# %%
df.working_flag.value_counts()
# Out:
# No     8846
# Yes    1610
# Name: working_flag, dtype: int64

# %% [markdown]
# ### following_company_page

# %%
df.following_company_page.value_counts()
# Out:
# No     7518
# Yes    2923
# 1        10
# 0         5
# Name: following_company_page, dtype: int64

# %%
df.following_company_page = df.following_company_page.replace('1','Yes')
df.following_company_page = df.following_company_page.replace('0','No')

# %%
df.following_company_page.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ### preferred_location_type

# %%
df.preferred_location_type.unique()
# Out:
# array(['Financial', 'Other', 'Medical', 'Game', 'Entertainment',
#        'Social media', 'Tour and Travel', 'Movie', 'OTT', 'Tour  Travel',
#        'Beach', 'Historical site', 'Big Cities', 'Trekking',
#        'Hill Stations'], dtype=object)

# %%
df.preferred_location_type = df.preferred_location_type.replace('Tour and Travel','Tour  Travel')
df.preferred_location_type = df.preferred_location_type.replace('OTT','Other')
df.preferred_location_type = df.preferred_location_type.replace('Movie','Other')

# %%
df.preferred_location_type.value_counts()
# Out:
# Beach              2424
# Financial          1876
# Historical site    1856
# Medical            1448
# Big Cities          636
# Other               591
# Trekking            528
# Social media        506
# Entertainment       383
# Hill Stations       108
# Tour  Travel         90
# Game                 10
# Name: preferred_location_type, dtype: int64

# %% [markdown]
# ### member_in_family

# %%
df.member_in_family.value_counts()
# Out:
# 3        4087
# 4        2844
# 2        1983
# 1        1192
# 5         331
# 10         10
# Three       9
# Name: member_in_family, dtype: int64

# %%
df.member_in_family = df.member_in_family.replace('Three','3')
#df.member_in_family = df.member_in_family.replace('10','5')

# %%
df.member_in_family.value_counts()
# Out:
# 3     4096
# 4     2844
# 2     1983
# 1     1192
# 5      331
# 10      10
# Name: member_in_family, dtype: int64

# %% [markdown]
# ###  preferred_device

# %%
df.preferred_device.value_counts()
# Out:
# Tab                4172
# iOS and Android    3247
# Laptop             1108
# iOS                 859
# Mobile              600
# Android             244
# Android OS          126
# ANDROID              97
# Other                 2
# Others                1
# Name: preferred_device, dtype: int64

# %%
df.preferred_device = df.preferred_device.replace('Android OS','Android')
df.preferred_device = df.preferred_device.replace('ANDROID','Android')
df.preferred_device = df.preferred_device.replace('Others','Other')

# %%
df.preferred_device.value_counts()
# Out:
# Tab                4172
# iOS and Android    3247
# Laptop             1108
# iOS                 859
# Mobile              600
# Android             467
# Other                 3
# Name: preferred_device, dtype: int64

# %% [markdown]
# ### Taken_product

# %%
df.Taken_product.value_counts()
# Out:
# No     8763
# Yes    1693
# Name: Taken_product, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10456 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        10456 non-null  int64
#  1   Taken_product                                 10456 non-null  object
#  2   Yearly_avg_view_on_travel_page                10456 non-null  float64
#  3   preferred_device                              10456 non-null  object
#  4   total_likes_on_outstation_checkin_given       10456 non-null  float64
#  5   yearly_avg_Outstation_checkins                10456 non-null  object
#  6   member_in_family                              10456 non-null  object
#  7   preferred_location_type                       10456 non-null  object
#  8   Yearly_avg_comment_on_travel_page             10456 non-null  float64
# ...

# %% [markdown]
# ## Continious Data

# %% [markdown]
# ### total_likes_on_outstation_checkin_given

# %%
df['total_likes_on_outstation_checkin_given'].describe(include = all)
# Out:
# count     10456.000000
# mean      28156.853673
# std       14215.275130
# min        3570.000000
# 25%       16317.000000
# 50%       28175.000000
# 75%       40526.750000
# max      152465.000000
# Name: total_likes_on_outstation_checkin_given, dtype: float64

# %%
df['total_likes_on_outstation_checkin_given'] = df['total_likes_on_outstation_checkin_given'].astype('int64')

# %%
sns.boxplot(df['total_likes_on_outstation_checkin_given'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outstation_checkin_given'>

# %%
print("0.5% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 0.5)))
print("  1% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 1)))
print("  5% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 5)))
print(" 10% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 10)))
print(" 90% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 90)))
print(" 95% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 95)))
print(" 99% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 99)))
print("99.5% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outstation_checkin_given'], 99.5)))
# Out:
# 0.5% properties have a price lower than  3861.03
#   1% properties have a price lower than  4104.55
#   5% properties have a price lower than  5747.75
#  10% properties have a price lower than  8457.00
#  90% properties have a price lower than  47495.00
#  95% properties have a price lower than  49876.25
#  99% properties have a price lower than  51983.45
# 99.5% properties have a price lower than  52229.00

# %%
df.total_likes_on_outstation_checkin_given.max()
# Out:
# 152465

# %%
df.total_likes_on_outstation_checkin_given.loc[df.total_likes_on_outstation_checkin_given > 52229.00]  = 52229.00
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df.total_likes_on_outstation_checkin_given.max()
# Out:
# 52229

# %% [markdown]
# ### week_since_last_outstation_checkin

# %%
print(df['week_since_last_outstation_checkin'].describe(include = all))
sns.boxplot(df['week_since_last_outstation_checkin'])
# Out:
# count    10456.000000
# mean         3.209162
# std          2.613645
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max         11.000000
# Name: week_since_last_outstation_checkin, dtype: float64
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week_since_last_outstation_checkin'>

# %% [markdown]
# ### Daily_Avg_mins_spend_on_traveling_page

# %%
print(df['Daily_Avg_mins_spend_on_traveling_page'].describe(include = all))
sns.boxplot(df['Daily_Avg_mins_spend_on_traveling_page'])
# Out:
# count    10456.000000
# mean        13.846787
# std          8.819214
# min          0.000000
# 25%          8.000000
# 50%         12.000000
# 75%         18.000000
# max        235.000000
# Name: Daily_Avg_mins_spend_on_traveling_page, dtype: float64
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Daily_Avg_mins_spend_on_traveling_page'>

# %%
print("0.5% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 0.5)))
print("  1% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 1)))
print("  5% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 5)))
print(" 10% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 10)))
print(" 90% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 90)))
print(" 95% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 95)))
print(" 99% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 99)))
print("99.5% properties have a price lower than {0: .2f}".format(np.percentile(df['Daily_Avg_mins_spend_on_traveling_page'], 99.5)))
# Out:
# 0.5% properties have a price lower than  1.00
#   1% properties have a price lower than  1.00
#   5% properties have a price lower than  3.00
#  10% properties have a price lower than  5.00
#  90% properties have a price lower than  26.00
#  95% properties have a price lower than  31.00
#  99% properties have a price lower than  38.00
# 99.5% properties have a price lower than  40.00

# %%
df.Daily_Avg_mins_spend_on_traveling_page.loc[df.Daily_Avg_mins_spend_on_traveling_page > 33.00]  = 33.00
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.boxplot(df['Daily_Avg_mins_spend_on_traveling_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Daily_Avg_mins_spend_on_traveling_page'>

# %% [markdown]
# ### montly_avg_comment_on_company_page

# %%
print(df['montly_avg_comment_on_company_page'].describe(include = all))
sns.boxplot(df['montly_avg_comment_on_company_page'])
# Out:
# count    10456.000000
# mean        28.917751
# std         47.619837
# min         11.000000
# 25%         18.000000
# 50%         23.000000
# 75%         28.000000
# max        499.000000
# Name: montly_avg_comment_on_company_page, dtype: float64
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='montly_avg_comment_on_company_page'>

# %%
print(" 95% properties have a price lower than {0: .2f}".format(np.percentile(df['montly_avg_comment_on_company_page'], 95)))
print(" 99% properties have a price lower than {0: .2f}".format(np.percentile(df['montly_avg_comment_on_company_page'], 99)))
print("99.5% properties have a price lower than {0: .2f}".format(np.percentile(df['montly_avg_comment_on_company_page'], 99.5)))
# Out:
#  95% properties have a price lower than  37.00
#  99% properties have a price lower than  366.35
# 99.5% properties have a price lower than  440.73

# %%
df.montly_avg_comment_on_company_page.loc[df.montly_avg_comment_on_company_page > 37.00]  = 37.00
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.boxplot(df['montly_avg_comment_on_company_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='montly_avg_comment_on_company_page'>

# %% [markdown]
# ### total_likes_on_outofstation_checkin_received

# %%
print(df['total_likes_on_outofstation_checkin_received'].describe(include = all))
sns.boxplot(df['total_likes_on_outofstation_checkin_received'])
# Out:
# count    10456.000000
# mean      6535.171194
# std       4706.525157
# min       1009.000000
# 25%       2946.750000
# 50%       4947.000000
# 75%       8396.500000
# max      20065.000000
# Name: total_likes_on_outofstation_checkin_received, dtype: float64
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outofstation_checkin_received'>

# %%
print(" 92% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outofstation_checkin_received'], 92)))
print(" 99% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outofstation_checkin_received'], 99)))
print("99.5% properties have a price lower than {0: .2f}".format(np.percentile(df['total_likes_on_outofstation_checkin_received'], 99.5)))
# Out:
#  92% properties have a price lower than  16428.60
#  99% properties have a price lower than  19662.35
# 99.5% properties have a price lower than  19840.62

# %%
df.total_likes_on_outofstation_checkin_received.loc[df.total_likes_on_outofstation_checkin_received > 16428]  = 16428
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.boxplot(df['total_likes_on_outofstation_checkin_received'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outofstation_checkin_received'>

# %% [markdown]
# ### Yearly_avg_comment_on_travel_page

# %%
print(df['Yearly_avg_comment_on_travel_page'].describe(include = all))
sns.boxplot(df['Yearly_avg_comment_on_travel_page'])
# Out:
# count    10456.000000
# mean        75.151109
# std         23.198149
# min          3.000000
# 25%         57.000000
# 50%         75.000000
# 75%         93.000000
# max        685.000000
# Name: Yearly_avg_comment_on_travel_page, dtype: float64
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_comment_on_travel_page'>

# %%
print(" 90% properties have a price lower than {0: .2f}".format(np.percentile(df['Yearly_avg_comment_on_travel_page'], 90)))
print(" 99% properties have a price lower than {0: .2f}".format(np.percentile(df['Yearly_avg_comment_on_travel_page'], 99)))
print("99.5% properties have a price lower than {0: .2f}".format(np.percentile(df['Yearly_avg_comment_on_travel_page'], 99.5)))
# Out:
#  90% properties have a price lower than  104.00
#  99% properties have a price lower than  117.00
# 99.5% properties have a price lower than  119.00

# %%
df.Yearly_avg_comment_on_travel_page.loc[df.Yearly_avg_comment_on_travel_page > 119.00]  = 119.00
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.boxplot(df['Yearly_avg_comment_on_travel_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_comment_on_travel_page'>

# %% [markdown]
# ## total_likes_on_outstation_checkin_given

# %%
print(df['total_likes_on_outstation_checkin_given'].describe(include = all))
sns.boxplot(df['total_likes_on_outstation_checkin_given'])
# Out:
# count    10456.000000
# mean     28136.939174
# std      14113.586565
# min       3570.000000
# 25%      16317.000000
# 50%      28175.000000
# 75%      40526.750000
# max      52229.000000
# Name: total_likes_on_outstation_checkin_given, dtype: float64
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outstation_checkin_given'>

# %% [markdown]
# ### Yearly_avg_view_on_travel_page

# %%
print(df['Yearly_avg_view_on_travel_page'].describe(include = all))
sns.boxplot(df['Yearly_avg_view_on_travel_page'])
# Out:
# count    10456.000000
# mean       281.266546
# std         68.272806
# min         35.000000
# 25%        232.000000
# 50%        271.000000
# 75%        325.000000
# max        464.000000
# Name: Yearly_avg_view_on_travel_page, dtype: float64
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_view_on_travel_page'>

# %%
print("0.5% properties have a price lower than {0: .2f}".format(np.percentile(df['Yearly_avg_view_on_travel_page'], 0.5)))
print("  1% properties have a price lower than {0: .2f}".format(np.percentile(df['Yearly_avg_view_on_travel_page'], 1)))
print("  5% properties have a price lower than {0: .2f}".format(np.percentile(df['Yearly_avg_view_on_travel_page'], 5)))
# Out:
# 0.5% properties have a price lower than  144.00
#   1% properties have a price lower than  151.00
#   5% properties have a price lower than  182.00

# %%
df.Yearly_avg_view_on_travel_page.loc[df.Yearly_avg_view_on_travel_page < 144.00]  = 144.00
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.boxplot(df['Yearly_avg_view_on_travel_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_view_on_travel_page'>

# %%
df.head()
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001           Yes                           307.0  iOS and Android
# 1  1000002            No                           367.0              iOS
# 2  1000003           Yes                           277.0  iOS and Android
# 3  1000004            No                           247.0              iOS
# 4  1000005            No                           202.0  iOS and Android
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                    38570                              1
# 1                                     9765                              1
# 2                                    48055                              1
# 3                                    48720                              1
# 4                                    20685                              1
#
# ...

# %% [raw]
# categorial columns:
#
# Taken_product
# preferred_device
# preferred_location_type
# following_company_page
# working_flag
# travelling_network_rating
# Adult_flag
#
# continous columns
#
# Yearly_avg_view_on_travel_page
# member_in_family
# week_since_last_outstation_checkin
# total_likes_on_outstation_checkin_given
# Yearly_avg_comment_on_travel_page
# total_likes_on_outofstation_checkin_received
# montly_avg_comment_on_company_page

# %% [markdown]
# # uni-varient analysis

# %% [markdown]
# ## categorical

# %%
sns.countplot(df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Taken_product', ylabel='count'>

# %%
df.Taken_product.value_counts(normalize=True)
# Out:
# No     0.838083
# Yes    0.161917
# Name: Taken_product, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(15,8)},)
sns.countplot(df['preferred_device'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='preferred_device', ylabel='count'>

# %%
sns.countplot(df['member_in_family'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='member_in_family', ylabel='count'>

# %%
sns.countplot(df['preferred_location_type'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='preferred_location_type', ylabel='count'>

# %%
sns.countplot(df['week_since_last_outstation_checkin'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week_since_last_outstation_checkin', ylabel='count'>

# %%
sns.countplot(df['following_company_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='following_company_page', ylabel='count'>

# %%
sns.countplot(df['working_flag'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='working_flag', ylabel='count'>

# %%
sns.countplot(df['travelling_network_rating'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='travelling_network_rating', ylabel='count'>

# %%
sns.countplot(df['Adult_flag'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Adult_flag', ylabel='count'>

# %% [markdown]
# ## continous variable

# %%
sns.distplot(df['Yearly_avg_view_on_travel_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly_avg_view_on_travel_page', ylabel='Density'>

# %%
sns.boxplot(df['Yearly_avg_view_on_travel_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_view_on_travel_page'>

# %%
sns.distplot(df['total_likes_on_outstation_checkin_given'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_likes_on_outstation_checkin_given', ylabel='Density'>

# %%
sns.boxplot(df['total_likes_on_outstation_checkin_given'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outstation_checkin_given'>

# %%
sns.distplot(df['Yearly_avg_comment_on_travel_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly_avg_comment_on_travel_page', ylabel='Density'>

# %%
sns.boxplot(df['Yearly_avg_comment_on_travel_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_comment_on_travel_page'>

# %%
sns.distplot(df['total_likes_on_outofstation_checkin_received'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_likes_on_outofstation_checkin_received', ylabel='Density'>

# %%
sns.boxplot(df['total_likes_on_outofstation_checkin_received'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outofstation_checkin_received'>

# %%
sns.distplot(df['montly_avg_comment_on_company_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='montly_avg_comment_on_company_page', ylabel='Density'>

# %%
sns.boxplot(df['montly_avg_comment_on_company_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='montly_avg_comment_on_company_page'>

# %%
sns.distplot(df['Daily_Avg_mins_spend_on_traveling_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily_Avg_mins_spend_on_traveling_page', ylabel='Density'>

# %%
sns.boxplot(df['Daily_Avg_mins_spend_on_traveling_page'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Daily_Avg_mins_spend_on_traveling_page'>

# %%
sns.distplot(df['week_since_last_outstation_checkin'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='week_since_last_outstation_checkin', ylabel='Density'>

# %%
sns.boxplot(df['week_since_last_outstation_checkin'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week_since_last_outstation_checkin'>

# %%
sns.distplot(df['total_likes_on_outofstation_checkin_received'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_likes_on_outofstation_checkin_received', ylabel='Density'>

# %%
sns.boxplot(df['total_likes_on_outofstation_checkin_received'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outofstation_checkin_received'>

# %% [markdown]
# # bivarient analysis

# %%
df.head()
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001           Yes                           307.0  iOS and Android
# 1  1000002            No                           367.0              iOS
# 2  1000003           Yes                           277.0  iOS and Android
# 3  1000004            No                           247.0              iOS
# 4  1000005            No                           202.0  iOS and Android
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                    38570                              1
# 1                                     9765                              1
# 2                                    48055                              1
# 3                                    48720                              1
# 4                                    20685                              1
#
# ...

# %%
sns.countplot(df['preferred_device'], hue=df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='preferred_device', ylabel='count'>

# %%
sns.countplot(df['member_in_family'],hue = df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='member_in_family', ylabel='count'>

# %%
sns.countplot(df['preferred_location_type'],hue = df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='preferred_location_type', ylabel='count'>

# %%
sns.countplot(df['following_company_page'],hue = df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='following_company_page', ylabel='count'>

# %%
sns.countplot(df['working_flag'],hue = df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='working_flag', ylabel='count'>

# %%
sns.countplot(df['travelling_network_rating'],hue = df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='travelling_network_rating', ylabel='count'>

# %%
sns.countplot(df['Adult_flag'],hue = df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Adult_flag', ylabel='count'>

# %%
# Yearly_avg_view_on_travel_page  
# total_likes_on_outstation_checkin_given  
# Yearly_avg_comment_on_travel_page  
# total_likes_on_outofstation_checkin_received  
# montly_avg_comment_on_company_page  
# Daily_Avg_mins_spend_on_traveling_page   
# week_since_last_outstation_checkin    
# total_likes_on_outstation_checkin_given

# %%
sns.set(rc = {'figure.figsize':(5,4)},)
sns.boxplot(df['Yearly_avg_view_on_travel_page'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_view_on_travel_page', ylabel='Taken_product'>

# %%
sns.boxplot(df['total_likes_on_outstation_checkin_given'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outstation_checkin_given', ylabel='Taken_product'>

# %%
sns.boxplot(df['Yearly_avg_comment_on_travel_page'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly_avg_comment_on_travel_page', ylabel='Taken_product'>

# %%
sns.boxplot(df['total_likes_on_outofstation_checkin_received'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outofstation_checkin_received', ylabel='Taken_product'>

# %%
sns.boxplot(df['montly_avg_comment_on_company_page'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='montly_avg_comment_on_company_page', ylabel='Taken_product'>

# %%
sns.boxplot(df['Daily_Avg_mins_spend_on_traveling_page'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Daily_Avg_mins_spend_on_traveling_page', ylabel='Taken_product'>

# %%
sns.boxplot(df['week_since_last_outstation_checkin'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week_since_last_outstation_checkin', ylabel='Taken_product'>

# %%
sns.boxplot(df['total_likes_on_outstation_checkin_given'], y =df['Taken_product'])
# Out:
# C:\Users\siddd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_likes_on_outstation_checkin_given', ylabel='Taken_product'>

# %% [markdown]
# # Multi varient analysis

# %%
#sns.pairplot(df)

# %%
plt.figure(figsize=(10,8))
sns.set(font_scale=1.2)
sns.heatmap(df[['Yearly_avg_view_on_travel_page','member_in_family','week_since_last_outstation_checkin','total_likes_on_outstation_checkin_given',
                'Yearly_avg_comment_on_travel_page','total_likes_on_outofstation_checkin_received','montly_avg_comment_on_company_page']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001           Yes                           307.0  iOS and Android
# 1  1000002            No                           367.0              iOS
# 2  1000003           Yes                           277.0  iOS and Android
# 3  1000004            No                           247.0              iOS
# 4  1000005            No                           202.0  iOS and Android
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                    38570                              1
# 1                                     9765                              1
# 2                                    48055                              1
# 3                                    48720                              1
# 4                                    20685                              1
#
# ...

# %% [markdown]
# # encoding

# %% [markdown]
# ### Taken_product

# %%
df.Taken_product = df.Taken_product.replace('Yes','1')
df.Taken_product = df.Taken_product.replace('No','0')

# %%
df.Taken_product.value_counts()
# Out:
# 0    8763
# 1    1693
# Name: Taken_product, dtype: int64

# %% [markdown]
# ### preferred_device

# %%
df.preferred_device.value_counts()
# Out:
# Tab                4172
# iOS and Android    3247
# Laptop             1108
# iOS                 859
# Mobile              600
# Android             467
# Other                 3
# Name: preferred_device, dtype: int64

# %%
df.preferred_device = df.preferred_device.replace('Tab','0')
df.preferred_device = df.preferred_device.replace('iOS and Android','1')
df.preferred_device = df.preferred_device.replace('Laptop','2')
df.preferred_device = df.preferred_device.replace('iOS','3')
df.preferred_device = df.preferred_device.replace('Mobile','4')
df.preferred_device = df.preferred_device.replace('Android','5')
df.preferred_device = df.preferred_device.replace('Other','6')

# %%
df.preferred_device.value_counts()
# Out:
# 0    4172
# 1    3247
# 2    1108
# 3     859
# 4     600
# 5     467
# 6       3
# Name: preferred_device, dtype: int64

# %% [markdown]
# ### preferred_location_type

# %%
df.preferred_location_type.value_counts()
# Out:
# Beach              2424
# Financial          1876
# Historical site    1856
# Medical            1448
# Big Cities          636
# Other               591
# Trekking            528
# Social media        506
# Entertainment       383
# Hill Stations       108
# Tour  Travel         90
# Game                 10
# Name: preferred_location_type, dtype: int64

# %%
df.preferred_location_type = df.preferred_location_type.replace('Financial','0')
df.preferred_location_type = df.preferred_location_type.replace('Other','1')
df.preferred_location_type = df.preferred_location_type.replace('Medical','2')
df.preferred_location_type = df.preferred_location_type.replace('Game','3')
df.preferred_location_type = df.preferred_location_type.replace('Entertainment','4')
df.preferred_location_type = df.preferred_location_type.replace('Social media','5')
df.preferred_location_type = df.preferred_location_type.replace('Tour  Travel','6')
df.preferred_location_type = df.preferred_location_type.replace('Beach','7')
df.preferred_location_type = df.preferred_location_type.replace('Historical site','8')
df.preferred_location_type = df.preferred_location_type.replace('Big Cities','9')
df.preferred_location_type = df.preferred_location_type.replace('Trekking','10')
df.preferred_location_type = df.preferred_location_type.replace('Hill Stations','11')

# %%
df.preferred_location_type.value_counts()
# Out:
# 7     2424
# 0     1876
# 8     1856
# 2     1448
# 9      636
# 1      591
# 10     528
# 5      506
# 4      383
# 11     108
# 6       90
# 3       10
# Name: preferred_location_type, dtype: int64

# %% [markdown]
# ### following_company_page

# %%
df.following_company_page.value_counts()
# Out:
# No     7523
# Yes    2933
# Name: following_company_page, dtype: int64

# %%
df.following_company_page = df.following_company_page.replace('Yes','1')
df.following_company_page = df.following_company_page.replace('No','0')

# %%
df.following_company_page.value_counts()
# Out:
# 0    7523
# 1    2933
# Name: following_company_page, dtype: int64

# %% [markdown]
# ### working_flag

# %%
df.working_flag.value_counts()
# Out:
# No     8846
# Yes    1610
# Name: working_flag, dtype: int64

# %%
df.working_flag = df.working_flag.replace('Yes','1')
df.working_flag = df.working_flag.replace('No','0')

# %%
df.working_flag.value_counts()
# Out:
# 0    8846
# 1    1610
# Name: working_flag, dtype: int64

# %%
df.head()
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001             1                           307.0                1
# 1  1000002             0                           367.0                3
# 2  1000003             1                           277.0                1
# 3  1000004             0                           247.0                3
# 4  1000005             0                           202.0                1
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                    38570                              1
# 1                                     9765                              1
# 2                                    48055                              1
# 3                                    48720                              1
# 4                                    20685                              1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10456 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        10456 non-null  int64
#  1   Taken_product                                 10456 non-null  object
#  2   Yearly_avg_view_on_travel_page                10456 non-null  float64
#  3   preferred_device                              10456 non-null  object
#  4   total_likes_on_outstation_checkin_given       10456 non-null  int64
#  5   yearly_avg_Outstation_checkins                10456 non-null  object
#  6   member_in_family                              10456 non-null  object
#  7   preferred_location_type                       10456 non-null  object
#  8   Yearly_avg_comment_on_travel_page             10456 non-null  float64
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# UserID
# Taken_product
# Yearly_avg_view_on_travel_page
# preferred_device
# total_likes_on_outstation_checkin_given
# yearly_avg_Outstation_checkins
# member_in_family
# preferred_location_type
# Yearly_avg_comment_on_travel_page
# total_likes_on_outofstation_checkin_received
# week_since_last_outstation_checkin
# following_company_page
# montly_avg_comment_on_company_page
# working_flag
# travelling_network_rating
# Adult_flag
# Daily_Avg_mins_spend_on_traveling_page

# %%
df.yearly_avg_Outstation_checkins.unique()
# Out:
# array(['1', '23', '16', '15', '26', '19', '24', '21', '11', '10', '25',
#        '12', '18', '29', '22', '20', '28', '14', '27', '13', '17', '*',
#        '5', '8', '2', '3', '9', '7', '6', '4'], dtype=object)

# %%
df.yearly_avg_Outstation_checkins.unique()
# Out:
# array(['1', '23', '16', '15', '26', '19', '24', '21', '11', '10', '25',
#        '12', '18', '29', '22', '20', '28', '14', '27', '13', '17', '*',
#        '5', '8', '2', '3', '9', '7', '6', '4'], dtype=object)

# %%
print(df['yearly_avg_Outstation_checkins']=="*")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11755    False
# 11756    False
# 11757    False
# 11758    False
# 11759    False
# Name: yearly_avg_Outstation_checkins, Length: 10456, dtype: bool

# %%
df = df[df['yearly_avg_Outstation_checkins'] != '*']

# %%
df = df.drop("UserID", axis = 1)

# %% [markdown]
# # Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
wardlink = linkage(df,method = 'ward')

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#   Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0             1                           307.0                1
# 1             0                           367.0                3
# 2             1                           277.0                1
# 3             0                           247.0                3
# 4             0                           202.0                1
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                    38570                              1
# 1                                     9765                              1
# 2                                    48055                              1
# 3                                    48720                              1
# 4                                    20685                              1
#
#   member_in_family preferred_location_type  Yearly_avg_comment_on_travel_page  \
# ...

# %%
X = df.drop("Taken_product" , axis=1)

y = df.pop("Taken_product")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1)
# train_labels = y_train

# %%
X_train.shape
# Out:
# (7318, 15)

# %%
y_train.shape
# Out:
# (7318,)

# %%
X_test.shape
# Out:
# (3137, 15)

# %%
y_test.shape
# Out:
# (3137,)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(criterion = 'gini' )

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
ytrain_predict = dt_model.predict(X_train)
ytest_predict = dt_model.predict(X_test)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
annr = MLPRegressor(hidden_layer_sizes=(500),random_state=123, max_iter=10000)#you are free to tweak the layer sizes
rfr = RandomForestRegressor(random_state=123)
dtr = tree.DecisionTreeRegressor(random_state=123)
regression_model = LinearRegression()

models=[regression_model,dtr,rfr,annr]

rmse_train=[]
rmse_test=[]
scores_train=[]
scores_test=[]

for i in models:  # we are scaling the data for ANN. Without scaling it will give very poor results. Computations becomes easier
    
    if (i != annr) :
        i.fit(X_train,y_train)
        scores_train.append(i.score(X_train, y_train))
        scores_test.append(i.score(X_test, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(X_train))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(X_test))))
 
    else :
        i.fit(X_train,y_train)
        scores_train.append(i.score(X_train, y_train))
        scores_test.append(i.score(X_test, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(X_train))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(X_test))))
        
print(pd.DataFrame({'Train RMSE': rmse_train,'Test RMSE': rmse_test,'Training Score':scores_train,'Test Score': scores_test},
            index=['Linear Regression','Decision Tree Regressor','Random Forest Regressor', 'ANN Regressor']))
# Out:
#                          Train RMSE  Test RMSE  Training Score  Test Score
# Linear Regression          0.337057   0.341806        0.150662    0.166655
# Decision Tree Regressor    0.000000   0.149380        1.000000    0.840834
# Random Forest Regressor    0.045210   0.114939        0.984719    0.905768
# ANN Regressor              1.153860   1.203903       -8.953617   -9.338296

# %% [markdown]
# ## grid search for DT

# %%
# param_grid = {
#     'max_depth': [10,15,20,25,30],# 3,5,7,9
#     'min_samples_leaf': [3,15,30], # 1-3% TRAIN DATA
#     'min_samples_split': [15,30,35,40,50],#3X min sample split
# }

# dtr=tree.DecisionTreeRegressor(random_state=123)

# grid_search = GridSearchCV(estimator = dtr, param_grid = param_grid, cv = 3)


# grid_search.fit(X_train,y_train)

# print(grid_search.best_params_)

# %% [markdown]
# ##  for RF

# %%
# param_grid = {
#     'max_depth': [7,10],
#     'max_features': [4, 6],#Sq root of the no. of ind features
#     'min_samples_leaf': [3, 15,30],
#     'min_samples_split': [30, 50,100],
#     'n_estimators': [300, 500] # Oob error rate
# }

# rfr = RandomForestRegressor(random_state=123)

# grid_search = GridSearchCV(estimator = rfr, param_grid = param_grid, cv = 3)

# %%
# grid_search.fit(X_train,y_train)

# %%
# print(grid_search.best_params_)

# %% [markdown]
# ##  for ANN

# %%
# param_grid = {
#     'hidden_layer_sizes':[500,(100,100)], #Nobs_train/a(Nvar)
#     # keeping these simple because it would take too much time to run on low-end computers
#     "activation": ["tanh", "relu"], 
#     "solver": ["sgd", "adam"]}

# annr = MLPRegressor(max_iter=10000, random_state=123)

# grid_search = GridSearchCV(estimator = annr, param_grid = param_grid, cv = 3)

# %%
# grid_search.fit(X_train,y_train)

# %%
# print(grid_search.best_params_)

# %%
annr = MLPRegressor(activation='tanh', hidden_layer_sizes=(500), 
                    solver='sgd',random_state=123, 
                    max_iter=10000)
rfr = RandomForestRegressor(max_depth=10, max_features=6, 
                            min_samples_leaf= 3,
                            min_samples_split= 30, n_estimators= 500,
                            random_state=123)
dtr = tree.DecisionTreeRegressor(max_depth=15,min_samples_split=15,min_samples_leaf=3,random_state=123)
regression_model = LinearRegression()

models=[regression_model,dtr,rfr,annr]

rmse_train=[]
rmse_test=[]
scores_train=[]
scores_test=[]


for i in models:
    if (i != annr):
        i.fit(X_train,y_train)
        scores_train.append(i.score(X_train, y_train))
        scores_test.append(i.score(X_test, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(X_train))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(X_test))))
        
    else :
        i.fit(X_train,y_train)
        scores_train.append(i.score(X_train, y_train))
        scores_test.append(i.score(X_test, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(X_train))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(X_test))))
        
        
print(pd.DataFrame({'Train RMSE': rmse_train,'Test RMSE': rmse_test,'Training Score':scores_train,'Test Score': scores_test},
            index=['Linear Regression','Decision Tree Regressor','Random Forest Regressor', 'ANN Regressor']))
# Out:
#                          Train RMSE  Test RMSE  Training Score  Test Score
# Linear Regression          0.337057   0.341806        0.150662    0.166655
# Decision Tree Regressor    0.129928   0.200836        0.873794    0.712295
# Random Forest Regressor    0.215941   0.246587        0.651386    0.566284
# ANN Regressor              0.372087   0.378887       -0.035055   -0.023964

# %%
from sklearn import metrics

# %% [markdown]
# # Linear regression

# %%
# LNR = LinearRegression()
# model_LNR=LNR.fit(X_train,y_train)
# y_predict = model_LNR.predict(X_test)
# model_LNR_score = model_LNR.score(X_test, y_test)
# print(model_LNR_score)
# print(metrics.confusion_matrix(y_test, y_predict))
# print(metrics.classification_report(y_test, y_predict))

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
y_predict = model_LR.predict(X_test)
model_LR_score = model_LR.score(X_test, y_test)
print(model_LR_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.8313675486133248
# [[2608    0]
#  [ 529    0]]
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      2608
#            1       0.00      0.00      0.00       529
#
#     accuracy                           0.83      3137
#    macro avg       0.42      0.50      0.45      3137
# weighted avg       0.69      0.83      0.75      3137
# C:\Users\siddd\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# # LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import scale

# %%
clf = LinearDiscriminantAnalysis()
model_LDA=clf.fit(X_train,y_train)
model_LDA
# Out:
# LinearDiscriminantAnalysis()

# %%
y_predict = model_LDA.predict(X_test)
model_LDA_score = model_LDA.score(X_test, y_test)

# %%
print(model_LDA_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.8498565508447561
# [[2527   81]
#  [ 390  139]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91      2608
#            1       0.63      0.26      0.37       529
#
#     accuracy                           0.85      3137
#    macro avg       0.75      0.62      0.64      3137
# weighted avg       0.83      0.85      0.82      3137

# %% [markdown]
# # SMOTE

# %%
#pip install -U imbalanced-learn

# %%
import imblearn
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE(random_state=1)
X_train, y_train = oversample.fit_resample(X_train, y_train)

# %%
counter=Counter(y)
counter
# Out:
# Counter({'1': 1693, '0': 8762})

# %%
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
y_predict = model_LR.predict(X_test)
model_LR_score = model_LR.score(X_test, y_test)
print(model_LR_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.6168313675486133
# [[1583 1025]
#  [ 177  352]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.61      0.72      2608
#            1       0.26      0.67      0.37       529
#
#     accuracy                           0.62      3137
#    macro avg       0.58      0.64      0.55      3137
# weighted avg       0.79      0.62      0.66      3137
# C:\Users\siddd\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf = LinearDiscriminantAnalysis()
model_LDA=clf.fit(X_train,y_train)
y_predict = model_LDA.predict(X_test)
model_LDA_score = model_LDA.score(X_test, y_test)
print(model_LDA_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.716289448517692
# [[1841  767]
#  [ 123  406]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      2608
#            1       0.35      0.77      0.48       529
#
#     accuracy                           0.72      3137
#    macro avg       0.64      0.74      0.64      3137
# weighted avg       0.84      0.72      0.75      3137

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
#To install xgboost library use - 
# !pip install xgboost 
from xgboost import XGBClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1,stratify=y)

# %% [markdown]
# # AdaBoost Classifier

# %%
abc = AdaBoostClassifier(random_state=1)
abc.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(random_state=1)

# %%
abc = AdaBoostClassifier(random_state=1)
abc.fit(X_train,y_train)

model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
y_predict = model_LR.predict(X_test)
model_LR_score = model_LR.score(X_test, y_test)
print(model_LR_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.8380618425247052
# [[2628    1]
#  [ 507    1]]
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2629
#            1       0.50      0.00      0.00       508
#
#     accuracy                           0.84      3137
#    macro avg       0.67      0.50      0.46      3137
# weighted avg       0.78      0.84      0.76      3137
# C:\Users\siddd\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf = LinearDiscriminantAnalysis()
model_LDA=clf.fit(X_train,y_train)
y_predict = model_LDA.predict(X_test)
model_LDA_score = model_LDA.score(X_test, y_test)
print(model_LDA_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.8559132929550526
# [[2552   77]
#  [ 375  133]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2629
#            1       0.63      0.26      0.37       508
#
#     accuracy                           0.86      3137
#    macro avg       0.75      0.62      0.64      3137
# weighted avg       0.83      0.86      0.83      3137

# %% [markdown]
# # bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %%
# bgcl = BaggingClassifier(base_estimator=dtr, n_estimators=50,random_state=123)

# %%
# bgcl = bgcl.fit(X_train, y_train)
# y_predict = bgcl.predict(X_test)

# %%
# print(bgcl.score(X_test , y_test))
# cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 50,random_state=1)
gbcl = gbcl.fit(X_train, y_train)

# %%
y_predict = gbcl.predict(X_test)
print(gbcl.score(X_test, y_test))
# Out:
# 0.8861970035065349

# %%
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
y_predict = model_LR.predict(X_test)
model_LR_score = model_LR.score(X_test, y_test)
print(model_LR_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.8380618425247052
# [[2628    1]
#  [ 507    1]]
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2629
#            1       0.50      0.00      0.00       508
#
#     accuracy                           0.84      3137
#    macro avg       0.67      0.50      0.46      3137
# weighted avg       0.78      0.84      0.76      3137
# C:\Users\siddd\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf = LinearDiscriminantAnalysis()
model_LDA=clf.fit(X_train,y_train)
y_predict = model_LDA.predict(X_test)
model_LDA_score = model_LDA.score(X_test, y_test)
print(model_LDA_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.8559132929550526
# [[2552   77]
#  [ 375  133]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2629
#            1       0.63      0.26      0.37       508
#
#     accuracy                           0.86      3137
#    macro avg       0.75      0.62      0.64      3137
# weighted avg       0.83      0.86      0.83      3137
